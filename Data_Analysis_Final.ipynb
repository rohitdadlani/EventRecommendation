# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the datasets
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
users = pd.read_csv("users.csv")
events = pd.read_csv("events.csv")
event_attendees = pd.read_csv("event_attendees.csv")
user_friends = pd.read_csv("user_friends.csv")

# Basic information about the datasets
def print_info(df, df_name):
    print(f"Info for {df_name}:")
    print(df.info())
    print("\n")

datasets = [(train, "train"), (test, "test"), (users, "users"), 
            (events, "events"), (event_attendees, "event_attendees"), (user_friends, "user_friends")]

for df, name in datasets:
    print_info(df, name)

# Check for missing values
def plot_missing_values(df, df_name):
    plt.figure(figsize=(10, 5))
    sns.heatmap(df.isnull(), cbar=False)
    plt.title(f'Missing values in {df_name} dataset')
    plt.show()

for df, name in datasets:
    plot_missing_values(df, name)

# Descriptive statistics for numerical features
def print_describe(df, df_name):
    print(f"Descriptive statistics for {df_name}:")
    print(df.describe())
    print("\n")

for df, name in datasets:
    if df.select_dtypes(include=['int64', 'float64']).columns.tolist():
        print_describe(df, name)

# Visualizing distributions and relations (example: user demographics)
plt.figure(figsize=(10, 5))
sns.countplot(x='gender', data=users)
plt.title('Distribution of Gender in Users Dataset')
plt.show()

plt.figure(figsize=(10, 5))
sns.histplot(users['birthyear'].dropna().astype(int), bins=30, kde=True)
plt.title('Distribution of Birth Years in Users Dataset')
plt.xlabel('Birth Year')
plt.show()

# Example of correlation matrix for the training data
plt.figure(figsize=(10, 8))
sns.heatmap(train.corr(), annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation Matrix for Train Dataset')
plt.show()

# Additional plots and analyses can be added here based on specific questions or interests
# Out:
# Info for train:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15398 entries, 0 to 15397
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   user            15398 non-null  int64
#  1   event           15398 non-null  int64
#  2   invited         15398 non-null  int64
#  3   timestamp       15398 non-null  object
#  4   interested      15398 non-null  int64
#  5   not_interested  15398 non-null  int64
# dtypes: int64(5), object(1)
# memory usage: 721.9+ KB
# None
#
#
# Info for test:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10237 entries, 0 to 10236
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   user       10237 non-null  int64
#  1   event      10237 non-null  int64
#  2   invited    10237 non-null  int64
#  3   timestamp  10237 non-null  object
# dtypes: int64(3), object(1)
# memory usage: 320.0+ KB
# None
#
#
# ...

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.9.2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the datasets
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
users = pd.read_csv("users.csv")
events = pd.read_csv("events.csv")
event_attendees = pd.read_csv("event_attendees.csv")
user_friends = pd.read_csv("user_friends.csv")

# Sampling the data to reduce memory usage during EDA
train_sample = train.sample(frac=0.1, random_state=1)
events_sample = events.sample(frac=0.1, random_state=1)

# Basic information about the datasets
def print_info(df, df_name):
    print(f"Info for {df_name}:")
    print(df.info())
    print("\n")

datasets = [(train_sample, "train"), (test, "test"), (users, "users"), 
            (events_sample, "events"), (event_attendees, "event_attendees"), (user_friends, "user_friends")]

for df, name in datasets:
    print_info(df, name)

# Check for missing values
def plot_missing_values(df, df_name):
    plt.figure(figsize=(10, 5))
    sns.heatmap(df.isnull(), cbar=False)
    plt.title(f'Missing values in {df_name} dataset')
    plt.show()

for df, name in datasets:
    plot_missing_values(df, name)

# Descriptive statistics for numerical features
def print_describe(df, df_name):
    print(f"Descriptive statistics for {df_name}:")
    print(df.describe())
    print("\n")

for df, name in datasets:
    if df.select_dtypes(include=['int64', 'float64']).columns.tolist():
        print_describe(df, name)

# Handling 'birthyear' data conversion issue
users['birthyear'] = pd.to_numeric(users['birthyear'], errors='coerce')
users.dropna(subset=['birthyear'], inplace=True)
users['birthyear'] = users['birthyear'].astype(int)

# Visualizing distributions and relations
plt.figure(figsize=(10, 5))
sns.countplot(x='gender', data=users)
plt.title('Distribution of Gender in Users Dataset')
plt.show()

plt.figure(figsize=(10, 5))
sns.histplot(users['birthyear'], bins=30, kde=True)
plt.title('Distribution of Birth Years in Users Dataset')
plt.xlabel('Birth Year')
plt.show()

# Correlation matrix for the training data
plt.figure(figsize=(10, 8))
sns.heatmap(train_sample.corr(), annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation Matrix for Train Dataset')
plt.show()

# Close plots to free up memory
plt.close('all')
# Out:
# Info for train:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1540 entries, 4694 to 3741
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   user            1540 non-null   int64
#  1   event           1540 non-null   int64
#  2   invited         1540 non-null   int64
#  3   timestamp       1540 non-null   object
#  4   interested      1540 non-null   int64
#  5   not_interested  1540 non-null   int64
# dtypes: int64(5), object(1)
# memory usage: 84.2+ KB
# None
#
#
# Info for test:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10237 entries, 0 to 10236
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   user       10237 non-null  int64
#  1   event      10237 non-null  int64
#  2   invited    10237 non-null  int64
#  3   timestamp  10237 non-null  object
# dtypes: int64(3), object(1)
# memory usage: 320.0+ KB
# None
#
#
# ...

# %%
###### Final EDA Start

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Load the datasets
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
users = pd.read_csv("users.csv")
events = pd.read_csv("events.csv")
event_attendees = pd.read_csv("event_attendees.csv")
user_friends = pd.read_csv("user_friends.csv")

# Sampling the data to reduce memory usage during EDA
train_sample = train.sample(frac=0.1, random_state=1)
events_sample = events.sample(frac=0.1, random_state=1)

# Basic information about the datasets
def print_info(df, df_name):
    print(f"Info for {df_name}:")
    print(df.info())
    print("\n")

datasets = [(train_sample, "train"), (test, "test"), (users, "users"), 
            (events_sample, "events"), (event_attendees, "event_attendees"), (user_friends, "user_friends")]

for df, name in datasets:
    print_info(df, name)

# Check for missing values
def plot_missing_values(df, df_name):
    plt.figure(figsize=(10, 5))
    sns.heatmap(df.isnull(), cbar=False)
    plt.title(f'Missing values in {df_name} dataset')
    plt.show()

for df, name in datasets:
    plot_missing_values(df, name)

# Descriptive statistics for numerical features
def print_describe(df, df_name):
    print(f"Descriptive statistics for {df_name}:")
    print(df.describe())
    print("\n")

for df, name in datasets:
    if df.select_dtypes(include=['int64', 'float64']).columns.tolist():
        print_describe(df, name)

# Handling 'birthyear' data conversion issue
users['birthyear'] = pd.to_numeric(users['birthyear'], errors='coerce')
users.dropna(subset=['birthyear'], inplace=True)
users['birthyear'] = users['birthyear'].astype(int)

# Visualizing distributions and relations
plt.figure(figsize=(10, 5))
sns.countplot(x='gender', data=users)
plt.title('Distribution of Gender in Users Dataset')
plt.show()

plt.figure(figsize=(10, 5))
sns.histplot(users['birthyear'], bins=30, kde=True)
plt.title('Distribution of Birth Years in Users Dataset')
plt.xlabel('Birth Year')
plt.show()

# Correlation matrix for the training data, excluding non-numeric columns
numeric_cols = train_sample.select_dtypes(include=[np.number]).columns.tolist()
plt.figure(figsize=(10, 8))
sns.heatmap(train_sample[numeric_cols].corr(), annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation Matrix for Train Dataset')
plt.show()

# Close plots to free up memory
plt.close('all')
# Out:
# Info for train:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1540 entries, 4694 to 3741
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   user            1540 non-null   int64
#  1   event           1540 non-null   int64
#  2   invited         1540 non-null   int64
#  3   timestamp       1540 non-null   object
#  4   interested      1540 non-null   int64
#  5   not_interested  1540 non-null   int64
# dtypes: int64(5), object(1)
# memory usage: 84.2+ KB
# None
#
#
# Info for test:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10237 entries, 0 to 10236
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   user       10237 non-null  int64
#  1   event      10237 non-null  int64
#  2   invited    10237 non-null  int64
#  3   timestamp  10237 non-null  object
# dtypes: int64(3), object(1)
# memory usage: 320.0+ KB
# None
#
#
# ...

# %%
# Distribution of 'locale' in the users dataset
plt.figure(figsize=(12, 6))
users['locale'].value_counts().plot(kind='bar')
plt.title('Distribution of User Locales')
plt.xlabel('Locale')
plt.ylabel('Frequency')
plt.show()

# Gender distribution
plt.figure(figsize=(8, 4))
sns.countplot(x='gender', data=users)
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
# Plot missing values for each column in the train dataset
plt.figure(figsize=(10, 6))
sns.heatmap(train.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Data in the Training Set')
plt.show()

# %%
# Boxplot for 'interested' to detect outliers
plt.figure(figsize=(8, 5))
sns.boxplot(x='interested', y='event', data=train_sample)
plt.title('Boxplot of Interested by Event')
plt.show()

# %%
# Pairplot for selected features
selected_features = ['invited', 'interested', 'not_interested']
sns.pairplot(train_sample[selected_features])
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Convert timestamp to datetime
train['timestamp'] = pd.to_datetime(train['timestamp'], errors='coerce')

# Set the index to the timestamp column for time-series analysis
train.set_index('timestamp', inplace=True)

# Resampling data monthly and plotting
train.resample('M').size().plot()
plt.title('Monthly Number of Events')
plt.ylabel('Number of Events')
plt.xlabel('Month')
plt.show()
# Out:
# C:\Users\rohit\AppData\Local\Temp\ipykernel_33904\1590088717.py:11: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   train.resample('M').size().plot()

# %%
from wordcloud import WordCloud

# Assuming 'events' DataFrame has a 'city' column
location_text = ' '.join(events['city'].dropna().astype(str))
wordcloud = WordCloud(width=800, height=400).generate(location_text)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud for Event Locations')
plt.show()

# %%
# Print the column names of the train DataFrame
print(train.columns)
# Out:
# Index(['user', 'event', 'invited', 'interested', 'not_interested'], dtype='object')

# %%
# Reset the index if 'timestamp' was previously set as the index
if 'timestamp' not in train.columns:
    train.reset_index(inplace=True)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Ensure the DataFrame is properly loaded and check the head to understand its structure
print(train.head())

# Convert 'timestamp' to datetime format if not already done
if 'timestamp' in train.columns and pd.api.types.is_string_dtype(train['timestamp']):
    train['timestamp'] = pd.to_datetime(train['timestamp'], errors='coerce')

# If 'timestamp' is the index and we need to use it for other operations, reset it temporarily
if 'timestamp' not in train.columns:
    train.reset_index(inplace=True)

# Ensure the index is unique if we're going to reset it back
if not train.index.is_unique:
    train.reset_index(drop=True, inplace=True)

# Feature engineering: Extracting the day of the week from 'timestamp'
train['day_of_week'] = train['timestamp'].dt.day_name()

# Reset index for safe plotting
train.reset_index(inplace=True, drop=True)

# Visualization of events count by day of the week
plt.figure(figsize=(10, 5))
sns.countplot(x='day_of_week', data=train)
plt.title('Number of Events by Day of the Week')
plt.xticks(rotation=45)
plt.show()
# Out:
#                                      user       event  invited  interested  \
# timestamp
# 2012-10-02 15:53:05.754000+00:00  3044012  1918771225        0           0
# 2012-10-02 15:53:05.754000+00:00  3044012  1502284248        0           0
# 2012-10-02 15:53:05.754000+00:00  3044012  2529072432        0           1
# 2012-10-02 15:53:05.754000+00:00  3044012  3072478280        0           0
# 2012-10-02 15:53:05.754000+00:00  3044012  1390707377        0           0
#
#                                   not_interested day_of_week
# timestamp
# 2012-10-02 15:53:05.754000+00:00               0     Tuesday
# 2012-10-02 15:53:05.754000+00:00               0     Tuesday
# 2012-10-02 15:53:05.754000+00:00               0     Tuesday
# 2012-10-02 15:53:05.754000+00:00               0     Tuesday
# 2012-10-02 15:53:05.754000+00:00               0     Tuesday

# %% [markdown]
# #Data Visualization
# 1. Univariate Analysis
# * Numerical Data

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Histogram
sns.histplot(train['numerical_column'], kde=True)
plt.title('Distribution of Numerical Column')
plt.show()

# Box Plot
sns.boxplot(x=train['numerical_column'])
plt.title('Box Plot for Numerical Column')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'numerical_column'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 5
#       2 import matplotlib.pyplot as plt
#       4 # Histogram
# ...

# %% [markdown]
# * Categorical Data

# %%
# Bar Chart
sns.countplot(x=train['categorical_column'])
plt.title('Distribution of Categorical Column')
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'categorical_column'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 2
#       1 # Bar Chart
# ...

# %% [markdown]
# 2. Bivariate Analysis:
# * Numerical vs. Numerical:

# %%
# Scatter Plot
sns.scatterplot(x=train['numerical_column1'], y=train['numerical_column2'])
plt.title('Scatter Plot between Two Numerical Columns')
plt.show()

# Correlation Matrix
correlation_matrix = train.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'numerical_column1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 2
#       1 # Scatter Plot
# ...

# %% [markdown]
# * Categorical vs. Numerical:

# %%
# Box Plot
sns.boxplot(x=train['categorical_column'], y=train['numerical_column'])
plt.title('Impact of Categorical on Numerical Column')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'categorical_column'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 2
#       1 # Box Plot
# ...

# %% [markdown]
# * Categorical vs. Categorical:

# %%
# Cross-tabulation
crosstab = pd.crosstab(train['categorical_column1'], train['categorical_column2'])
sns.heatmap(crosstab, annot=True, cmap='Blues')
plt.title('Heatmap of Two Categorical Columns')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'categorical_column1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 2
#       1 # Cross-tabulation
# ...

# %% [markdown]
# #Data Preprocessing

# %% [markdown]
# * Handling Missing Values

# %%
from sklearn.impute import SimpleImputer

# Numerical imputation
imputer = SimpleImputer(strategy='median')
train['numerical_column'] = imputer.fit_transform(train[['numerical_column']])

# Categorical imputation
imputer = SimpleImputer(strategy='most_frequent')
train['categorical_column'] = imputer.fit_transform(train[['categorical_column']])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 from sklearn.impute import SimpleImputer
#       3 # Numerical imputation
#       4 imputer = SimpleImputer(strategy='median')
#
# ModuleNotFoundError: No module named 'sklearn.impute'

# %% [markdown]
# * Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
train['scaled_numerical'] = scaler.fit_transform(train[['numerical_column']])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 from sklearn.preprocessing import StandardScaler
#       3 scaler = StandardScaler()
#       4 train['scaled_numerical'] = scaler.fit_transform(train[['numerical_column']])
#
# ModuleNotFoundError: No module named 'sklearn.preprocessing'

# %% [markdown]
# * Encoding Categorical Variables

# %%
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(sparse=False)
encoded_features = encoder.fit_transform(train[['categorical_column']])
train = train.join(pd.DataFrame(encoded_features, columns=encoder.get_feature_names_out()))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 from sklearn.preprocessing import OneHotEncoder
#       3 encoder = OneHotEncoder(sparse=False)
#       4 encoded_features = encoder.fit_transform(train[['categorical_column']])
#
# ModuleNotFoundError: No module named 'sklearn.preprocessing'

# %% [markdown]
# * Feature Engineering:

# %%
train['interaction_feature'] = train['numerical_column1'] * train['numerical_column2']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'numerical_column1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 1
# ...

# %% [markdown]
# * Splitting Data:

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(train.drop('target_column', axis=1), train['target_column'], test_size=0.2, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 from sklearn.model_selection import train_test_split
#       3 X_train, X_test, y_train, y_test = train_test_split(train.drop('target_column', axis=1), train['target_column'], test_size=0.2, random_state=42)
#
# ModuleNotFoundError: No module named 'sklearn.model_selection'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split

# Assuming you have already loaded your DataFrame into 'train'
# Replace 'actual_numerical_column_name' and 'actual_categorical_column_name' with your real column names

# Example column names
numerical_column = 'age'  # replace 'age' with your actual numerical column name
categorical_column = 'gender'  # replace 'gender' with your actual categorical column name

# Data Visualization
## Univariate Analysis
### Numerical Data
# Histogram
sns.histplot(train[numerical_column], kde=True)
plt.title(f'Distribution of {numerical_column}')
plt.show()

# Box Plot
sns.boxplot(x=train[numerical_column])
plt.title(f'Box Plot for {numerical_column}')
plt.show()

### Categorical Data
# Bar Chart
sns.countplot(x=train[categorical_column])
plt.title(f'Distribution of {categorical_column}')
plt.xticks(rotation=45)
plt.show()

# Data Preprocessing
## Handling Missing Values
### Numerical imputation
imputer = SimpleImputer(strategy='median')
train[numerical_column] = imputer.fit_transform(train[[numerical_column]])

### Categorical imputation
imputer = SimpleImputer(strategy='most_frequent')
train[categorical_column] = imputer.fit_transform(train[[categorical_column]])

## Feature Scaling
scaler = StandardScaler()
train[f'scaled_{numerical_column}'] = scaler.fit_transform(train[[numerical_column]])

## Encoding Categorical Variables
encoder = OneHotEncoder(sparse=False)
encoded_features = encoder.fit_transform(train[[categorical_column]])
train = train.join(pd.DataFrame(encoded_features, columns=encoder.get_feature_names_out()))

## Splitting Data
#X_train, X_test, y_train, y_test = train_test_split(train.drop('target_column', axis=1), train['target_column'], test_size=0.2, random_state=42)

# Ensure 'target_column' is the name of your actual target column
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[47], line 4
#       2 import seaborn as sns
#       3 import matplotlib.pyplot as plt
# ----> 4 from sklearn.impute import SimpleImputer
#       5 from sklearn.preprocessing import StandardScaler, OneHotEncoder
#       6 from sklearn.model_selection import train_test_split
#
# File ~\anaconda3\lib\site-packages\sklearn\impute\__init__.py:5
#       1 """Transformers for missing value imputation."""
#       3 import typing
# ----> 5 from ._base import MissingIndicator, SimpleImputer
#       6 from ._knn import KNNImputer
#       8 if typing.TYPE_CHECKING:
#       9     # Avoid errors in type checkers (e.g. mypy) for experimental estimators.
#      10     # TODO: remove this check once the estimator is no longer experimental.
#
# File ~\anaconda3\lib\site-packages\sklearn\impute\_base.py:15
#      12 import numpy.ma as ma
# ...

# %%
from sklearn.impute import SimpleImputer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 from sklearn.impute import SimpleImputer
#
# File ~\anaconda3\lib\site-packages\sklearn\impute\__init__.py:5
#       1 """Transformers for missing value imputation."""
#       3 import typing
# ----> 5 from ._base import MissingIndicator, SimpleImputer
#       6 from ._knn import KNNImputer
#       8 if typing.TYPE_CHECKING:
#       9     # Avoid errors in type checkers (e.g. mypy) for experimental estimators.
#      10     # TODO: remove this check once the estimator is no longer experimental.
#
# File ~\anaconda3\lib\site-packages\sklearn\impute\_base.py:15
#      12 import numpy.ma as ma
#      13 from scipy import sparse as sp
# ---> 15 from ..base import BaseEstimator, TransformerMixin, _fit_context
#      16 from ..utils._mask import _get_mask
# ...

# %%
import sklearn

# %%
import sys
print(sys.path)  # Check if the paths are correctly pointing to your environment
# Out:
# ['C:\\Users\\rohit\\anaconda3\\python39.zip', 'C:\\Users\\rohit\\anaconda3\\DLLs', 'C:\\Users\\rohit\\anaconda3\\lib', 'C:\\Users\\rohit\\anaconda3', '', 'C:\\Users\\rohit\\anaconda3\\lib\\site-packages', 'C:\\Users\\rohit\\anaconda3\\lib\\site-packages\\win32', 'C:\\Users\\rohit\\anaconda3\\lib\\site-packages\\win32\\lib', 'C:\\Users\\rohit\\anaconda3\\lib\\site-packages\\Pythonwin', 'C:\\Users\\rohit\\anaconda3\\lib\\site-packages\\setuptools\\_vendor']
